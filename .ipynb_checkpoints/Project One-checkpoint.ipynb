# %%
# %matplotlib inline
from modsim import *
from pandas import read_html
from numpy import random
import numpy as np
import matplotlib.pyplot as plt

table1 = read_html('USASAC2015-Report#27-2014-Activities 8.html')
product_tables = read_html('USASAC2015-Report#27-2014-Activities 10.html')
table2= read_html('USASAC2015-Report#27-2014-Activities 97-11.html')
table3 = read_html('USASAC2015-Report#27-2014-Activities 98-12.html')
return_97 = table2[0]
return_98 = table3[0]
return_97.columns = ['year','fst', 'second','thrid', 'repeat', 'total','hatchery', 'natural']
return_98.columns = ['year','fst', 'second','thrid', 'repeat', 'total','hatchery', 'natural']
differ = return_98.total - return_97.total

# %%
aqua_prdt = product_tables[0]
aqua_prdt.columns = ['year','production']
#aqua_prdt.production[15] = 2381
aqua_prdt.index = aqua_prdt.year
#aqua_prdt

# %%
salmon_pop = table1[0]
salmon_pop.columns = ['year','fst', 'second','thrid', 'repeat', 'total','hatchery', 'natural']
salmon_pop.index = salmon_pop.year
#salmon_popu = salmon_pop.hatchery + salmon_pop.natural
pop_total = salmon_pop.natural + salmon_pop.hatchery
#salmon_pop.fst

# %%
newfig()
plot(salmon_pop.index, salmon_pop.total, 'bs:', label = 'salmon returns')
decorate(title = 'Atlantic Salmon Returns over Years',
         xlabel = 'Year',
         ylabel = 'Salmon Returns')
savefig('Salmon_Population.pdf')
# Out:
# Saving figure to file Salmon_Population.pdf

# %%
newfig()
#plot(aqua_prdt.index, aqua_prdt.production/50, 'go:')
#plot(aqua_prdt.index, differ)
plot(aqua_prdt.index, aqua_prdt.production, 'go:', label = 'Aquaculture Production')
decorate(title = 'Atlantic Salmon Returns over Years',
         xlabel = 'Year',
         ylabel = 'Salmon Returns')
savefig('Aquaculture.pdf')
# Out:
# Saving figure to file Aquaculture.pdf

# %%
a = np.random.rand(1, 5)

# %%
for i in a:
    print(i*100)
# Out:
# [ 42.42670534  31.7107929   21.20265899  17.67095672  80.58767076]

# %%
b = 10000 + np.random.randn(5) * 2500
np.mean(b)
# Out:
# 10438.523291510784

# %%
mu, sigma = 10000, 2500
x = mu + sigma*np.random.randn(10000)
#x = log(x)
n, bins, patches = plt.hist(x, bins = 50)
plt.show()
#salmon_pop.first

# %%
salmon = System(t0 = salmon_pop.index[0],
                t_end = salmon_pop.index[-1],
                p0 = salmon_pop.total[salmon_pop.index[0]],
                fishing = 3000)

def run_simulation1(system):salmon = System(t0 = salmon_pop.index[0],
                t_end = salmon_pop.index[-1],
                p0 = salmon_pop.total[salmon_pop.index[0]],
                fishing = 3000)

def run_simulation1(system):
    system.returns = TimeSeries()
    system.returns[system.t0] = system.p0
    mu, sigma = 300, 200
    for year in linrange(system.t0, system.t_end):
        birth = mu + sigma*np.random.randn(1, 1)
        system.fishing = 3000 + 1000*np.random.randn(1, 1)
        system.returns[year+1] = system.returns[year] + birth - system.fishing/10
        if system.returns[year+1] < 0:
            print('No salmon to fish')
            break
    return system.returns

def decoration():
    decorate(title = '',
             xlabel = 'Years',
             ylabel = 'Atlantic Salmon Returns',
             legend = True)
    
results = run_simulation1(salmon)
plot(results, 'bo:', label = 'Atlantic Salmon Population')
decoration()
    system.returns = TimeSeries()
    system.returns[system.t0] = system.p0
    mu, sigma = 300, 200
    for year in linrange(system.t0, system.t_end):
        birth = mu + sigma*np.random.randn(1, 1)
        system.fishing = 3000 + 1000*np.random.randn(1, 1)
        system.returns[year+1] = system.returns[year] + birth - system.fishing/10
        if system.returns[year+1] < 0:
            print('No salmon to fish')
            break
    return system.returns

def decoration():
    decorate(title = '',
             xlabel = 'Years',
             ylabel = 'Atlantic Salmon Returns',
             legend = True)
    
results = run_simulation1(salmon)
plot(results, 'bo:', label = 'Atlantic Salmon Population')
decoration()
# Out:
#   File "<ipython-input-211-e878c64e5a32>", line 33
#     system.returns = TimeSeries()
#     ^
# IndentationError: unexpected indent

# %%
#mu + sigma*np.random.randn(1, 1)

# %%
salmon = System(t0 = salmon_pop.index[0],
                t_end = salmon_pop.index[-1],
                p0 = salmon_pop.total[salmon_pop.index[0]],
                fishing = 3000)

def salmon_update(system, t):
    '''
    n = None
    if system.returns[t] < 3000:
        n = .5 + 0.01 * np.random.randn(1)
    elif 7500 > system.returns[t] > 3000:
        n = .2 + 0.05 * np.random.randn(1)
    elif system.returns[t] > 7500:
        n = .05 + .01 * np.random.randn(1)
    pop = system.returns[t] * (1+.5)'''
    mu, sigma = 300, 120
    growth = mu + sigma*np.random.randn(1, 1)
    return growth

def prdt_update(system, mu, t):
    n = 1
    if system.returns[t] > 10000:
        n = 12
    prdt = mu * n + system.sigma * np.random.randn(1)
    return prdt / 20
                          
def run_simulation2(system, update_function1, update_function2, mu):
    system.returns = TimeSeries()
    system.returns[system.t0] = system.p0
    
    for year in range(system.t0, system.t_end):
        #Look Here
        #Current mu is the population
        #Comment out the following line and run run_simulation2(mu = values_to_sweep)
        mu = system.returns[year]
        #mu = 8986
        
        fishing = update_function2(system, mu, year) 
        if system.returns[year] - fishing < 0:
            print('No salmon to fish!')
            break
        system.returns[year+1] = system.returns[year] - fishing + update_function1(system, year)
    return system.returns

salmon = System(t0 = salmon_pop.index[0],
                t_end = salmon_pop.index[-1],
                p0 = salmon_pop.total[salmon_pop.index[0]],
                sigma = 4035)

newfig()

for i  in range(5):
    returns = run_simulation2(salmon, salmon_update, prdt_update, mu = 8496)
#30% Aquation
    plot(returns)

# %%
def run_simulation3(update_function1, update_function2, mu):
    system = System(t0 = salmon_pop.index[0],
                    t_end = salmon_pop.index[-1],
                    p0 = salmon_pop.total[salmon_pop.index[0]],
                    sigma = 4035)
    t_end = 2500
    #print(mu)
    
    system.returns = TimeSeries()
    system.returns[system.t0] = system.p0
    for year in range(system.t0, system.t_end):
        #Look Here
        #Current mu is the population
        #Comment out the following line and run run_simulation2(mu = values_to_sweep)
        #mu = system.returns[year]
        #mu = 8968
        
        fishing = update_function2(system, mu, year) 
        if system.returns[year] - fishing < 0:
            #print('No salmon to fish!')
            #print(mu)
            index = int(mu)
            #print(index)
            years_to_extinct[index] = year - system.t0
            break
        system.returns[year+1] = system.returns[year] - fishing + update_function1(system, year)
    return system

# %%
def salmon_update(system, t):
    '''
    n = None
    if system.returns[t] < 3000:
        n = .5 + 0.01 * np.random.randn(1)
    elif 7500 > system.returns[t] > 3000:
        n = .2 + 0.05 * np.random.randn(1)
    elif system.returns[t] > 7500:
        n = .05 + .01 * np.random.randn(1)
    pop = system.returns[t] * (1+.5)'''
    mu, sigma = 250, 100
    growth = mu + sigma*np.random.randn(1, 1)
    return growth

# %%
years_to_extinct = TimeSeries()
newfig()
for prdt_mu in linrange(2000, 15000, 100):
    salmon = run_simulation3(salmon_update, prdt_update, prdt_mu)
#years_to_extinct[5000] = 150
#years_to_extinct[7500] = 100
#years_to_extinct[10000] = 50
    plot(years_to_extinct, 'go', label = 'Years to Extinction')

def decoration():
    decorate(title = 'Years to Extinction vs Aquatural Production',
             xlabel = 'Aquacultural Production(Metric Tons)',
             ylabel = 'Years to Extinction',
             legend = True)
decoration()
savefig('chap03-fig01.pdf')
# Out:
# Saving figure to file chap03-fig01.pdf

# %%
def run_simulation4(update_function1, update_function2, mu):
    system = System(t0 = salmon_pop.index[0],
                    t_end = salmon_pop.index[-1],
                    p0 = salmon_pop.total[salmon_pop.index[0]],
                    prdt_mu = 8968,
                    sigma = 4035)
    t_end = 2500
    #print(mu)
    system.returns = TimeSeries()
    system.returns[system.t0] = system.p0
    for year in range(system.t0, system.t_end):
        #Look Here
        #Current mu is the population
        #Comment out the following line and run run_simulation2(mu = values_to_sweep)
        #mu = system.returns[year]
        
        
        fishing = update_function2(system, prdt_mu, year) 
        if system.returns[year] - fishing < 0:
            #print('No salmon to fish!')
            #print(mu)
            index = int(mu)
            #print(index)
            years_to_extinct[index] = year - system.t0
            break
        system.returns[year+1] = system.returns[year] - fishing
    return system
